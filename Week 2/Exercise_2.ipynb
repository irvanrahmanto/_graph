# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('facebook_combined.txt', sep="  ")

G = nx.read_edgelist('facebook_combined.txt', create_using=nx.Graph(), nodetype=int)
# plt.figure(figsize=(30,30))
plt.figure(figsize=(20,20))
# pos=nx.spring_layout(G, k=0.15)
pos=nx.spring_layout(G)


# nx.draw_networkx(G,pos,node_size=25, node_color='red')
# plt.show()

ec = nx.eigenvector_centrality(G)
# node_size = [v*10000 for v in ec.values()]

cc = nx

# cb = nx.betweenness_centrality(G, normalized=True, endpoints=True)
node_size = [v*1000 for v in cb.values()]
node_color = [10000*G.degree(v) for v in G]
nx.draw_networkx(G, pos, node_size=node_size, node_color=node_color)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
